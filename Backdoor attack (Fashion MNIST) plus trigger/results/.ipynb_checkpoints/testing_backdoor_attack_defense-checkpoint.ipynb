# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
with open('fashion_mnist_ba_plus_rounds_0', 'rb') as f:
    rounds = pickle.load(f)

# %%
#marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
marker = itertools.cycle(('o', 'v', '^', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('fashion_mnist_ba_plus_acc_0', 'rb') as f:
    acc_0 = pickle.load(f)

# %%
with open('fashion_mnist_ba_plus_basr_0', 'rb') as f:
    basr_0 = pickle.load(f)

# %%
with open('fashion_mnist_ba_plus_acc_3', 'rb') as f:
    acc_3 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_3', 'rb') as f:
    basr_3 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_6', 'rb') as f:
    acc_6 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_6', 'rb') as f:
    basr_6 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_9', 'rb') as f:
    acc_9 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_9', 'rb') as f:
    basr_9 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_12', 'rb') as f:
    acc_12 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_12', 'rb') as f:
    basr_12 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_15', 'rb') as f:
    acc_15 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_15', 'rb') as f:
    basr_15 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_18', 'rb') as f:
    acc_18 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_18', 'rb') as f:
    basr_18 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_21', 'rb') as f:
    acc_21 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_21', 'rb') as f:
    basr_21 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_24', 'rb') as f:
    acc_24 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_24', 'rb') as f:
    basr_24 = pickle.load(f)
with open('fashion_mnist_ba_plus_acc_27', 'rb') as f:
    acc_27 = pickle.load(f)
with open('fashion_mnist_ba_plus_basr_27', 'rb') as f:
    basr_27 = pickle.load(f)

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_3[0][:50],'bv',label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_3[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_3[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_3[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center')
#plt.savefig('fashion_mnist_ba_plus_10_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_6[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_6[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_6[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_6[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center')
#plt.savefig('fashion_mnist_ba_plus_20_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_9[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_9[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_9[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_9[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_30_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_12[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_12[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_12[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_12[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_40_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_15[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_15[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_15[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_15[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_50_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_18[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_18[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_18[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_18[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_60_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_21[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_21[1][:50],'y',label='main-acc with defense')
plt.plot(rounds[0][:50], basr_21[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_21[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_70_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_24[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_24[1][:50],'y',marker=next(marker),label='main-acc with defense')
plt.plot(rounds[0][:50], basr_24[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_24[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_80_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc-no-attacker')
plt.plot(rounds[0][:50], acc_27[0][:50],'b',marker=next(marker),label='main-acc with attacker')
plt.plot(rounds[0][:50], acc_27[1][:50],'y',marker=next(marker),label='main-acc with defense')
plt.plot(rounds[0][:50], basr_27[0][:50],'r',marker=next(marker),label='backdoor asr without defense')
plt.plot(rounds[0][:50], basr_27[1][:50],'g',marker=next(marker),label='backdoor asr with defense')
#plt.title('Accuracy vs Communication rounds in Pixel-pattern backdoor attack')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
#colors = ['black','cyan', 'magenta','red','green']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['main-acc-no-attacker','main-acc with attacker', 'main-acc with defense','backdoor asr without defense','backdoor asr with defense']
#plt.legend(lines, labels)
plt.legend(loc='center right')
#plt.savefig('fashion_mnist_ba_plus_90_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_9[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_9[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_9[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_9[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.legend(loc='right')
#plt.savefig('fm_ba_plus_30_percent',bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_18[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_18[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_18[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_18[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.legend(loc='right')
#plt.savefig('fm_ba_plus_60_percent',bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_27[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_27[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_27[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_27[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.legend(loc='right')
#plt.savefig('fm_ba_plus_90_percent',bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_9[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_9[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_9[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_9[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend(loc='right')
plt.savefig('grid_fm_ba_plus_30_percent',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_18[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_18[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_18[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_18[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend(loc='right')
plt.savefig('grid_fm_ba_plus_60_percent',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_27[0][:50],'b',marker=next(marker),label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_27[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_27[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_27[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend(loc='right')
plt.savefig('grid_fm_ba_plus_90_percent',dpi=300,bbox_inches='tight')
