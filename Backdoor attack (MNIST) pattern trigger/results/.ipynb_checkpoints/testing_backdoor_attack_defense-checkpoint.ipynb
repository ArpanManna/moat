# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
with open('mnist_ba_rounds_0', 'rb') as f:
    rounds = pickle.load(f)

# %%
#marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
marker = itertools.cycle(('o', 'v', '^', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('mnist_ba_acc_0', 'rb') as f:
    acc_0 = pickle.load(f)

# %%
with open('mnist_ba_basr_0', 'rb') as f:
    basr_0 = pickle.load(f)

# %%
with open('mnist_ba_acc_3', 'rb') as f:
    acc_3 = pickle.load(f)
with open('mnist_ba_basr_3', 'rb') as f:
    basr_3 = pickle.load(f)
with open('mnist_ba_acc_6', 'rb') as f:
    acc_6 = pickle.load(f)
with open('mnist_ba_basr_6', 'rb') as f:
    basr_6 = pickle.load(f)
with open('mnist_ba_acc_9', 'rb') as f:
    acc_9 = pickle.load(f)
with open('mnist_ba_basr_9', 'rb') as f:
    basr_9 = pickle.load(f)
with open('mnist_ba_acc_12', 'rb') as f:
    acc_12 = pickle.load(f)
with open('mnist_ba_basr_12', 'rb') as f:
    basr_12 = pickle.load(f)
with open('mnist_ba_acc_15', 'rb') as f:
    acc_15 = pickle.load(f)
with open('mnist_ba_basr_15', 'rb') as f:
    basr_15 = pickle.load(f)
with open('mnist_ba_acc_18', 'rb') as f:
    acc_18 = pickle.load(f)
with open('mnist_ba_basr_18', 'rb') as f:
    basr_18 = pickle.load(f)
with open('mnist_ba_acc_21', 'rb') as f:
    acc_21 = pickle.load(f)
with open('mnist_ba_basr_21', 'rb') as f:
    basr_21 = pickle.load(f)
with open('mnist_ba_acc_24', 'rb') as f:
    acc_24 = pickle.load(f)
with open('mnist_ba_basr_24', 'rb') as f:
    basr_24 = pickle.load(f)
with open('mnist_ba_acc_27', 'rb') as f:
    acc_27 = pickle.load(f)
with open('mnist_ba_basr_27', 'rb') as f:
    basr_27 = pickle.load(f)

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_3[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_3[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_3[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_3[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend(loc='center')
#plt.savefig('mnist_ba_pattern_10_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_6[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_6[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_6[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_6[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_20_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_9[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_9[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_9[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_9[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_30_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_12[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_12[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_12[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_12[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_40_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_15[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_15[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_15[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_15[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_50_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_18[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_18[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_18[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_18[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_60_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_21[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_21[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_21[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_21[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_70_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_24[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_24[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_24[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_24[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_80_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_27[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_27[1][:50],'y',marker=next(marker),label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_27[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_27[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.legend()
#plt.savefig('mnist_ba_pattern_90_percent')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_9[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_9[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_9[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_9[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_mnist_ba_pattern_30_percent',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_18[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_18[1][:50],'y',label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_18[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_18[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_mnist_ba_pattern_60_percent',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0][:50], acc_0[0][:50],'ko',label='main-acc (baseline)')
plt.plot(rounds[0][:50], acc_27[0][:50],'bv',label='main-acc (attack)')
plt.plot(rounds[0][:50], acc_27[1][:50],'y',marker=next(marker),label='main-acc (Moat)')
plt.plot(rounds[0][:50], basr_27[0][:50],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds[0][:50], basr_27[1][:50],'g',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rate / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_mnist_ba_pattern_90_percent',dpi=300,bbox_inches='tight')
