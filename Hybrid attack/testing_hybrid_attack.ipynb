# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
with open('fashion_mnist_pattern_acc_9', 'rb') as f:
    acc = pickle.load(f)

# %%
marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
#marker = itertools.cycle(('o', 'v', '^', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('fashion_mnist_pattern_basr_9', 'rb') as f:
    basr = pickle.load(f)

# %%
with open('fashion_mnist_pattern_asr_9', 'rb') as f:
    asr = pickle.load(f)

# %%
with open('fashion_mnist_pattern_mcr_9', 'rb') as f:
    mcr = pickle.load(f)

# %%
with open('fashion_mnist_pattern_tmcr_9', 'rb') as f:
    tmcr = pickle.load(f)

# %%
with open('fashion_mnist_pattern_rounds_9', 'rb') as f:
    rounds = pickle.load(f)

# %%
plt.plot(rounds[0],acc[1],'m',marker=next(marker),label='Attack')
plt.plot(rounds[1],acc[0],'b',marker=next(marker),label='Defense (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('main task accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('fm_lfa_ba_acc_9',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0],asr[1],'m',marker=next(marker),label='Attack')
plt.plot(rounds[1],asr[0],'b',marker=next(marker),label='Defense (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('label flip attack success rates')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('fm_lfa_ba_asr_9',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0],basr[1],'m',marker=next(marker),label='Attack')
plt.plot(rounds[1],basr[0],'b',marker=next(marker),label='Defense (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('backdoor success rates')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('fm_lfa_ba_basr_9',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0],mcr[0],'m',marker=next(marker),label='attack')
plt.plot(rounds[1],mcr[1],'b',marker=next(marker),label='defense')
plt.xlabel('communication rounds')
plt.ylabel('misclassification rates')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('fm_lfa_ba_mcr_9',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds[0],tmcr[0],'m',marker=next(marker),label='attack')
plt.plot(rounds[1],tmcr[1],'b',marker=next(marker),label='defense')
plt.xlabel('communication rounds')
plt.ylabel('targeted misclassification rates')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('fm_lfa_ba_tmcr_9',dpi=300,bbox_inches='tight')
