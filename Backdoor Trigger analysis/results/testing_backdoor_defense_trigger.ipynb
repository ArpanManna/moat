# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
with open('rounds_size', 'rb') as f:
    rounds_size = pickle.load(f)

# %%
marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('acc_size', 'rb') as f:
    acc_size = pickle.load(f)

# %%
with open('basr_size', 'rb') as f:
    basr_size = pickle.load(f)

# %%
with open('rounds_gap', 'rb') as f:
    rounds_gap = pickle.load(f)
with open('acc_gap', 'rb') as f:
    acc_gap = pickle.load(f)
with open('basr_gap', 'rb') as f:
    basr_gap = pickle.load(f)

# %%
with open('rounds_pos', 'rb') as f:
    rounds_pos = pickle.load(f)
with open('acc_pos', 'rb') as f:
    acc_pos = pickle.load(f)
with open('basr_pos', 'rb') as f:
    basr_pos = pickle.load(f)

# %%
plt.plot(rounds_size[0],acc_size[0],color='orange',marker=next(marker),label='main acc (attack)')
plt.plot(rounds_size[1],acc_size[1],'b',marker=next(marker),label='main acc (Moat)')
plt.plot(rounds_size[0],basr_size[0],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds_size[1],basr_size[1],'c',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_fm_ba_trigger_size',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds_gap[0],acc_gap[0],color='orange',marker=next(marker),label='main acc (attack)')
plt.plot(rounds_gap[1],acc_gap[1],'b',marker=next(marker),label='main acc (Moat)')
plt.plot(rounds_gap[0],basr_gap[0],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds_gap[1],basr_gap[1],'c',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_fm_ba_trigger_gap',dpi=300,bbox_inches='tight')

# %%
plt.plot(rounds_pos[0],acc_pos[0],color='orange',marker=next(marker),label='main acc (attack)')
plt.plot(rounds_pos[1],acc_pos[1],'b',marker=next(marker),label='main acc (Moat)')
plt.plot(rounds_pos[0],basr_pos[0],'r',marker=next(marker),label='backdoor asr (attack)')
plt.plot(rounds_pos[1],basr_pos[1],'c',marker=next(marker),label='backdoor asr (Moat)')
plt.xlabel('communication rounds')
plt.ylabel('attack success rates / accuracy')
plt.grid(color='b', ls = '-.', lw = 0.2)
plt.legend()
plt.savefig('grid_fm_ba_trigger_pos',dpi=300,bbox_inches='tight')
