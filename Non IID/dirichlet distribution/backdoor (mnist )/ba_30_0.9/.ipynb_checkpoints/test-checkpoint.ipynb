# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
with open('fashion_mnist_ba_pattern_rounds_9_0.9', 'rb') as f:
    rounds = pickle.load(f)

# %%
marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
#marker = itertools.cycle(('o', 'v', '^', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('acc_attack_0.9', 'rb') as f:
    acc_attack = pickle.load(f)

# %%
with open('acc_defense_0.9', 'rb') as f:
    acc_defense = pickle.load(f)

# %%
with open('basr_attack_0.9', 'rb') as f:
    basr_attack = pickle.load(f)

# %%
with open('basr_defense_0.9', 'rb') as f:
    basr_defense = pickle.load(f)

# %%
alpha = [0.9]

# %%
for i in range(len(basr_attack)):
    plt.plot(rounds[0],basr_attack[i],marker=next(marker),label='attack α={}'.format(alpha[i]))
    plt.plot(rounds[0],basr_defense[i],marker=next(marker),label='defense α={}'.format(alpha[i]))
plt.xlabel('communicaton rounds')
plt.ylabel('backdoor success rates')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.plot(rounds[0],acc[0],label='attack')
for i in range(1,len(rounds)):
    plt.plot(rounds[i],acc[i],label='threshold = {}'.format(i*0.1+1.7))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c1dc634462ac> in <module>
# ----> 1 plt.plot(rounds[0],acc[0],label='attack')
#       2 for i in range(1,len(rounds)):
#       3     plt.plot(rounds[i],acc[i],label='threshold = {}'.format(i*0.1+1.7))
#       4 plt.legend()
#
# NameError: name 'acc' is not defined

# %% [markdown]
# # Plot accuracy all % attackers

# %%
plt.plot(rounds[0][10:],acc[0][10:],marker=next(marker),label='attack')
for i in range(1,len(rounds)):
    plt.plot(rounds[i][10:],acc[i][10:],marker=next(marker),label='threshold = {}'.format(i*0.1+1.7))
plt.legend()

# %% [markdown]
# # Plot attack success rate

# %%
plt.plot(rounds[0],asr[0],label='attack',marker=next(marker))
for i in range(1,len(rounds)):
    plt.plot(rounds[i],asr[i],marker=next(marker),label='threshold = {:.1f}'.format(1.8 + i*0.1))
plt.legend()

# %%
#plt.plot(rounds[0],asr[0],label='attack',marker=next(marker))
for i in range(1,len(rounds)):
    plt.plot(rounds[i],asr[i],marker=next(marker),label='threshold = {:.1f}'.format(i*0.1+1.8))
plt.legend()

# %% [markdown]
# # Plot misclassification rate

# %%
plt.plot(rounds[0],mcr[0],label='attack')
for i in range(1,len(rounds)):
    plt.plot(rounds[i],mcr[i],marker=next(marker),label='threshold = {}'.format(i*0.1+1.7))
plt.legend()

# %% [markdown]
# # Plot targeted misclassification rate

# %%
plt.plot(rounds[0],t_mcr[0],label='attack')
for i in range(1,len(rounds)):
    plt.plot(rounds[i],t_mcr[i],marker=next(marker),label='threshold = {}'.format(i*0.1+1.7))
plt.legend()

# %% [markdown]
# # Rounds 20-50 without marker
