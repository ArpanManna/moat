# %%
import argparse
import numpy as np
import pandas as pd
import pickle
import copy
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets,transforms
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, TensorDataset
import os
import random
from tqdm import tqdm
import torch.nn.functional as F
from collections import Counter
from itertools import islice
import itertools

# %%
def intToRoman(num):
 
     # Storing roman values of digits from 0-9 
     # when placed at different places
     m = [ "", "m", "mm", "mmm" ]
     c = [ "", "c", "cc", "ccc", "cd", "d", 
           "dc", "dcc", "dccc", "cm "]
     x = [ "", "x", "xx", "xxx", "xl", "l", 
           "lx", "lxx", "lxxx", "xc" ]
     i = [ "", "i", "ii", "iii", "iv", "v", 
           "vi", "vii", "viii", "ix"]
          
     # Converting to roman
     thousands = m[num // 1000]
     hundereds = c[(num % 1000) // 100]
     tens =  x[(num % 100) // 10]
     ones = i[num % 10]
          
     ans = (thousands + hundereds +
                 tens + ones)
          
     return ans;

# %%
for i in range(1,16):
    print(intToRoman(i))
# Out:
# i
# ii
# iii
# iv
# v
# vi
# vii
# viii
# ix
# x
# xi
# xii
# xiii
# xiv
# xv

# %%
with open('comm_rounds_fashion_lfa_3', 'rb') as f:
    rounds = pickle.load(f)

# %%
#marker = itertools.cycle(('o', 'v', '^', 's', '8', '<', '>','p'))
marker = itertools.cycle(('o', 'v', '^', '>','p'))
from matplotlib.lines import Line2D

# %%
with open('accuracy_fashion_lfa_3', 'rb') as f:
    acc_3 = pickle.load(f)

# %%
with open('asr_lfa_3', 'rb') as f:
    asr_3 = pickle.load(f)

# %%
with open('mcr_lfa_3', 'rb') as f:
    mcr_3 = pickle.load(f)

# %%
with open('t_mcr_lfa_3', 'rb') as f:
    t_mcr_3 = pickle.load(f)

# %%
with open('accuracy_fashion_lfa_6', 'rb') as f:
    acc_6 = pickle.load(f)
with open('asr_lfa_6', 'rb') as f:
    asr_6 = pickle.load(f)
with open('mcr_lfa_6', 'rb') as f:
    mcr_6 = pickle.load(f)
with open('t_mcr_lfa_6', 'rb') as f:
    t_mcr_6 = pickle.load(f)
with open('accuracy_fashion_lfa_9', 'rb') as f:
    acc_9 = pickle.load(f)
with open('asr_lfa_9', 'rb') as f:
    asr_9 = pickle.load(f)
with open('mcr_lfa_9', 'rb') as f:
    mcr_9 = pickle.load(f)
with open('t_mcr_lfa_9', 'rb') as f:
    t_mcr_9 = pickle.load(f)
with open('accuracy_fashion_lfa_12', 'rb') as f:
    acc_12 = pickle.load(f)
with open('asr_lfa_12', 'rb') as f:
    asr_12 = pickle.load(f)
with open('mcr_lfa_12', 'rb') as f:
    mcr_12 = pickle.load(f)
with open('t_mcr_lfa_12', 'rb') as f:
    t_mcr_12 = pickle.load(f)
with open('accuracy_fashion_lfa_15', 'rb') as f:
    acc_15 = pickle.load(f)
with open('asr_lfa_15', 'rb') as f:
    asr_15 = pickle.load(f)
with open('mcr_lfa_15', 'rb') as f:
    mcr_15 = pickle.load(f)
with open('t_mcr_lfa_15', 'rb') as f:
    t_mcr_15 = pickle.load(f)
with open('accuracy_fashion_lfa_18', 'rb') as f:
    acc_18 = pickle.load(f)
with open('asr_lfa_18', 'rb') as f:
    asr_18 = pickle.load(f)
with open('mcr_lfa_18', 'rb') as f:
    mcr_18 = pickle.load(f)
with open('t_mcr_lfa_18', 'rb') as f:
    t_mcr_18 = pickle.load(f)
with open('accuracy_fashion_lfa_21', 'rb') as f:
    acc_21 = pickle.load(f)
with open('asr_lfa_21', 'rb') as f:
    asr_21 = pickle.load(f)
with open('mcr_lfa_21', 'rb') as f:
    mcr_21 = pickle.load(f)
with open('t_mcr_lfa_21', 'rb') as f:
    t_mcr_21 = pickle.load(f)
with open('accuracy_fashion_lfa_24', 'rb') as f:
    acc_24 = pickle.load(f)
with open('asr_lfa_24', 'rb') as f:
    asr_24 = pickle.load(f)
with open('mcr_lfa_24', 'rb') as f:
    mcr_24 = pickle.load(f)
with open('t_mcr_lfa_24', 'rb') as f:
    t_mcr_24 = pickle.load(f)
with open('accuracy_fashion_lfa_27', 'rb') as f:
    acc_27 = pickle.load(f)
with open('asr_lfa_27', 'rb') as f:
    asr_27 = pickle.load(f)
with open('mcr_lfa_27', 'rb') as f:
    mcr_27 = pickle.load(f)
with open('t_mcr_lfa_27', 'rb') as f:
    t_mcr_27 = pickle.load(f)

# %%
with open('accuracy_fashion_lfa_0', 'rb') as f:
    acc_0 = pickle.load(f)
with open('asr_lfa_0', 'rb') as f:
    asr_0 = pickle.load(f)
with open('mcr_lfa_0', 'rb') as f:
    mcr_0 = pickle.load(f)
with open('t_mcr_lfa_0', 'rb') as f:
    t_mcr_0 = pickle.load(f)

# %% [markdown]
# # Plot accuracy all % attackers

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))

axes[0,0].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,0].plot(rounds[0][:50], acc_3[0][:50],color='orange',marker=next(marker),label='attack')
axes[0,0].plot(rounds[0][:50], acc_3[1][:50],'b',marker=next(marker),label='defense')
#axes[0,0].set_xlabel('communication rounds')
axes[0,0].set_ylabel('accuracy')

axes[0,1].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,1].plot(rounds[0][:50], acc_6[0][:50],color='orange',marker=next(marker),label='attack')
axes[0,1].plot(rounds[0][:50], acc_6[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[0,1].set_ylabel('accuracy')

axes[0,2].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,2].plot(rounds[0][:50], acc_9[0][:50],color='orange',marker=next(marker),label='attack')
axes[0,2].plot(rounds[0][:50], acc_9[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[0,2].set_ylabel('accuracy')

axes[1,0].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,0].plot(rounds[0][:50], acc_12[0][:50],color='orange',marker=next(marker),label='attack')
axes[1,0].plot(rounds[0][:50], acc_12[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[1,0].set_ylabel('accuracy')

axes[1,1].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,1].plot(rounds[0][:50], acc_15[0][:50],color='orange',marker=next(marker),label='attack')
axes[1,1].plot(rounds[0][:50], acc_15[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[1,1].set_ylabel('accuracy')

axes[1,2].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,2].plot(rounds[0][:50], acc_18[0][:50],color='orange',marker=next(marker),label='attack')
axes[1,2].plot(rounds[0][:50], acc_18[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[1,2].set_ylabel('accuracy')

axes[2,0].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,0].plot(rounds[0][:50], acc_21[0][:50],color='orange',marker=next(marker),label='attack')
axes[2,0].plot(rounds[0][:50], acc_21[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[2,0].set_ylabel('accuracy')

axes[2,1].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,1].plot(rounds[0][:50], acc_24[0][:50],color='orange',marker=next(marker),label='attack')
axes[2,1].plot(rounds[0][:50], acc_24[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[2,1].set_ylabel('accuracy')

axes[2,2].plot(rounds[0][:50], acc_0[0][:50],'k',marker=next(marker),label='baseline(no attack)')
axes[2,2].plot(rounds[0][:50], acc_27[0][:50],color='orange',marker=next(marker),label='attack')
axes[2,2].plot(rounds[0][:50], acc_27[1][:50],'b',marker=next(marker),label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[2,2].set_ylabel('accuracy')


attack_percent = 10
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    i += 1
for i in range(3):
    for j in range(3):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
        attack_percent += 10
#        a += 1
#colors = ['black','red','blue']
#lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
#labels = ['no attacker','attack','defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
#plt.legend()
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_acc_all')

# %% [markdown]
# # Plot attack success rate

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))


axes[0,0].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,0].plot(rounds[0][:50], asr_3[0][:50],'c',marker=next(marker),label='attack')
axes[0,0].plot(rounds[0][:50], asr_3[1][:50],'b',marker=next(marker),label='defense')

axes[0,1].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,1].plot(rounds[0][:50], asr_6[0][:50],'c',marker=next(marker),label='attack')
axes[0,1].plot(rounds[0][:50], asr_6[1][:50],'b',marker=next(marker),label='defense')

axes[0,2].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,2].plot(rounds[0][:50], asr_9[0][:50],'c',marker=next(marker),label='attack')
axes[0,2].plot(rounds[0][:50], asr_9[1][:50],'b',marker=next(marker),label='defense')

axes[1,0].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,0].plot(rounds[0][:50], asr_12[0][:50],'c',marker=next(marker),label='attack')
axes[1,0].plot(rounds[0][:50], asr_12[1][:50],'b',marker=next(marker),label='defense')

axes[1,1].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,1].plot(rounds[0][:50], asr_15[0][:50],'c',marker=next(marker),label='attack')
axes[1,1].plot(rounds[0][:50], asr_15[1][:50],'b',marker=next(marker),label='defense')

axes[1,2].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,2].plot(rounds[0][:50], asr_18[0][:50],'c',marker=next(marker),label='attack')
axes[1,2].plot(rounds[0][:50], asr_18[1][:50],'b',marker=next(marker),label='defense')

axes[2,0].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,0].plot(rounds[0][:50], asr_21[0][:50],'c',marker=next(marker),label='attack')
axes[2,0].plot(rounds[0][:50], asr_21[1][:50],'b',marker=next(marker),label='defense')

axes[2,1].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,1].plot(rounds[0][:50], asr_24[0][:50],'c',marker=next(marker),label='attack')
axes[2,1].plot(rounds[0][:50], asr_24[1][:50],'b',marker=next(marker),label='defense')

axes[2,2].plot(rounds[0][:50], asr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,2].plot(rounds[0][:50], asr_27[0][:50],'c',marker=next(marker),label='attack')
axes[2,2].plot(rounds[0][:50], asr_27[1][:50],'b',marker=next(marker),label='defense')


attack_percent = 10
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    ax.set(ylabel='attack success rates')
    i += 1
for i in range(3):
    for j in range(3):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
        attack_percent += 10
#        a += 1
colors = ['black','cyan','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline (no attacker)','attack','defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_asr_all')

# %% [markdown]
# # Plot misclassification rate

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))

axes[0,0].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,0].plot(rounds[0][:50], mcr_3[0][:50],'m',marker=next(marker),label='attack')
axes[0,0].plot(rounds[0][:50], mcr_3[1][:50],'c',marker=next(marker),label='defense')

axes[0,1].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,1].plot(rounds[0][:50], mcr_6[0][:50],'m',marker=next(marker),label='attack')
axes[0,1].plot(rounds[0][:50], mcr_6[1][:50],'c',marker=next(marker),label='defense')

axes[0,2].plot(rounds[0][:50], mcr_9[0][:50],'k',marker=next(marker),label='no attack')
axes[0,2].plot(rounds[0][:50], mcr_9[0][:50],'m',marker=next(marker),label='attack')
axes[0,2].plot(rounds[0][:50], mcr_9[1][:50],'c',marker=next(marker),label='defense')

axes[1,0].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,0].plot(rounds[0][:50], mcr_12[0][:50],'m',marker=next(marker),label='attack')
axes[1,0].plot(rounds[0][:50], mcr_12[1][:50],'c',marker=next(marker),label='defense')

axes[1,1].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,1].plot(rounds[0][:50], mcr_15[0][:50],'m',marker=next(marker),label='attack')
axes[1,1].plot(rounds[0][:50], mcr_15[1][:50],'c',marker=next(marker),label='defense')

axes[1,2].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,2].plot(rounds[0][:50], mcr_18[0][:50],'m',marker=next(marker),label='attack')
axes[1,2].plot(rounds[0][:50], mcr_18[1][:50],'c',marker=next(marker),label='defense')

axes[2,0].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,0].plot(rounds[0][:50], mcr_21[0][:50],'m',marker=next(marker),label='attack')
axes[2,0].plot(rounds[0][:50], mcr_21[1][:50],'c',marker=next(marker),label='defense')

axes[2,1].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,1].plot(rounds[0][:50], mcr_24[0][:50],'m',marker=next(marker),label='attack')
axes[2,1].plot(rounds[0][:50], mcr_24[1][:50],'c',marker=next(marker),label='defense')

axes[2,2].plot(rounds[0][:50], mcr_0[0][:50],'k',marker=next(marker),label='baseline(no attack)')
axes[2,2].plot(rounds[0][:50], mcr_27[0][:50],'m',marker=next(marker),label='attack')
axes[2,2].plot(rounds[0][:50], mcr_27[1][:50],'c',marker=next(marker),label='defense')


attack_percent = 10
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    ax.set(ylabel='global misclassification rates')
    i += 1
for i in range(3):
    for j in range(3):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
        attack_percent += 10
#        a += 1
colors = ['black','magenta','cyan']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['no attacker','attack','defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_mcr_all')

# %% [markdown]
# # Plot targeted misclassification rate

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))

axes[0,0].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,0].plot(rounds[0][:50], t_mcr_3[0][:50],'r',marker=next(marker),label='attack')
axes[0,0].plot(rounds[0][:50], t_mcr_3[1][:50],'b',marker=next(marker),label='defense')

axes[0,1].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,1].plot(rounds[0][:50], t_mcr_6[0][:50],'r',marker=next(marker),label='attack')
axes[0,1].plot(rounds[0][:50], t_mcr_6[1][:50],'b',marker=next(marker),label='defense')

axes[0,2].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[0,2].plot(rounds[0][:50], t_mcr_9[0][:50],'r',marker=next(marker),label='attack')
axes[0,2].plot(rounds[0][:50], t_mcr_9[1][:50],'b',marker=next(marker),label='defense')

axes[1,0].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,0].plot(rounds[0][:50], t_mcr_12[0][:50],'r',marker=next(marker),label='attack')
axes[1,0].plot(rounds[0][:50], t_mcr_12[1][:50],'b',marker=next(marker),label='defense')

axes[1,1].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,1].plot(rounds[0][:50], t_mcr_15[0][:50],'r',marker=next(marker),label='attack')
axes[1,1].plot(rounds[0][:50], t_mcr_15[1][:50],'b',marker=next(marker),label='defense')

axes[1,2].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[1,2].plot(rounds[0][:50], t_mcr_18[0][:50],'r',marker=next(marker),label='attack')
axes[1,2].plot(rounds[0][:50], t_mcr_18[1][:50],'b',marker=next(marker),label='defense')

axes[2,0].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,0].plot(rounds[0][:50], t_mcr_21[0][:50],'r',marker=next(marker),label='attack')
axes[2,0].plot(rounds[0][:50], t_mcr_21[1][:50],'b',marker=next(marker),label='defense')

axes[2,1].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,1].plot(rounds[0][:50], t_mcr_24[0][:50],'r',marker=next(marker),label='attack')
axes[2,1].plot(rounds[0][:50], t_mcr_24[1][:50],'b',marker=next(marker),label='defense')


axes[2,2].plot(rounds[0][:50], t_mcr_0[0][:50],'k',marker=next(marker),label='no attack')
axes[2,2].plot(rounds[0][:50], t_mcr_27[0][:50],'r',marker=next(marker),label='attack')
axes[2,2].plot(rounds[0][:50], t_mcr_27[1][:50],'b',marker=next(marker),label='defense')

attack_percent = 10
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    ax.set(ylabel='targeted misclassification rates')
    i += 1
for i in range(3):
    for j in range(3):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
        attack_percent += 10
#        a += 1
colors = ['black','red','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline (no attacker)','attack','defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_tmcr_all')

# %% [markdown]
# # Rounds 20-50 without marker

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 11))

axes[0,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[0,0].plot(rounds[0][:50], acc_6[0][:50],'r',label='attack')
axes[0,0].plot(rounds[0][:50], acc_6[1][:50],'g',label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[0,0].set_ylabel('accuracy')

axes[0,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[0,1].plot(rounds[0][:50], asr_6[0][:50],'m',label='attack')
axes[0,1].plot(rounds[0][:50], asr_6[1][:50],'c',label='defense')
#axes[1,1].set_xlabel('communication rounds')
axes[0,1].set_ylabel('attack success rate')

axes[0,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[0,2].plot(rounds[0][:50], mcr_6[0][:50],color='indigo',label='attack')
axes[0,2].plot(rounds[0][:50], mcr_6[1][:50],color='sienna',label='defense')
#axes[1,2].set_xlabel('communication rounds')
axes[0,2].set_ylabel('misclassification rate')

axes[0,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[0,3].plot(rounds[0][:50], t_mcr_6[0][:50],color='orange',label='attack')
axes[0,3].plot(rounds[0][:50], t_mcr_6[1][:50],'b',label='defense')
#axes[1,3].set_xlabel('communication rounds')
axes[0,3].set_ylabel('targeted misclassification rate')

axes[1,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[1,0].plot(rounds[0][:50], acc_9[0][:50],'r',label='attack')
axes[1,0].plot(rounds[0][:50], acc_9[1][:50],'g',label='defense')
#axes[2,0].set_xlabel('communication rounds')
axes[1,0].set_ylabel('accuracy')

axes[1,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[1,1].plot(rounds[0][:50], asr_9[0][:50],'m',label='attack')
axes[1,1].plot(rounds[0][:50], asr_9[1][:50],'c',label='defense')
#axes[2,1].set_xlabel('communication rounds')
axes[1,1].set_ylabel('attack success rate')

axes[1,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[1,2].plot(rounds[0][:50], mcr_9[0][:50],color='indigo',label='attack')
axes[1,2].plot(rounds[0][:50], mcr_9[1][:50],color='sienna',label='defense')
#axes[2,2].set_xlabel('communication rounds')
axes[1,2].set_ylabel('misclassification rate')

axes[1,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[1,3].plot(rounds[0][:50], t_mcr_9[0][:50],color='orange',label='attack')
axes[1,3].plot(rounds[0][:50], t_mcr_9[1][:50],'b',label='defense')
#axes[2,3].set_xlabel('communication rounds')
axes[1,3].set_ylabel('targeted misclassification rate')

axes[2,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[2,0].plot(rounds[0][:50], acc_12[0][:50],'r',label='attack')
axes[2,0].plot(rounds[0][:50], acc_12[1][:50],'g',label='defense')
#axes[3,0].set_xlabel('communication rounds')
axes[2,0].set_ylabel('accuracy')

axes[2,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[2,1].plot(rounds[0][:50], asr_12[0][:50],'m',label='attack')
axes[2,1].plot(rounds[0][:50], asr_12[1][:50],'c',label='defense')
#axes23,1].set_xlabel('communication rounds')
axes[2,1].set_ylabel('attack success rate')

axes[2,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[2,2].plot(rounds[0][:50], mcr_12[0][:50],color='indigo',label='attack')
axes[2,2].plot(rounds[0][:50], mcr_12[1][:50],color='sienna',label='defense')
#axes[3,2].set_xlabel('communication rounds')
axes[2,2].set_ylabel('misclassification rate')

axes[2,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[2,3].plot(rounds[0][:50], t_mcr_12[0][:50],color='orange',label='attack')
axes[2,3].plot(rounds[0][:50], t_mcr_12[1][:50],'b',label='defense')
#axes[3,3].set_xlabel('communication rounds')
axes[2,3].set_ylabel('targeted misclassification rate')

axes[3,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[3,0].plot(rounds[0][:50], acc_15[0][:50],'r',label='attack')
axes[3,0].plot(rounds[0][:50], acc_15[1][:50],'g',label='defense')
#axes[4,0].set_xlabel('communication rounds')
axes[3,0].set_ylabel('accuracy')

axes[3,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[3,1].plot(rounds[0][:50], asr_15[0][:50],'m',label='attack')
axes[3,1].plot(rounds[0][:50], asr_15[1][:50],'c',label='defense')
#axes[4,1].set_xlabel('communication rounds')
axes[3,1].set_ylabel('attack success rate')

axes[3,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[3,2].plot(rounds[0][:50], mcr_15[0][:50],color='indigo',label='attack')
axes[3,2].plot(rounds[0][:50], mcr_15[1][:50],color='sienna',label='defense')
#axes[4,2].set_xlabel('communication rounds')
axes[3,2].set_ylabel('misclassification rate')

axes[3,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[3,3].plot(rounds[0][:50], t_mcr_15[0][:50],color='orange',label='attack')
axes[3,3].plot(rounds[0][:50], t_mcr_15[1][:50],'b',label='defense')
#axes[4,3].set_xlabel('communication rounds')
axes[3,3].set_ylabel('targeted misclassification rate')


#axes[0,0].set_ylabel('reconstruction loss')
#axes[1,0].set_ylabel('reconstruction loss')
#axes[2,0].set_ylabel('reconstruction loss')
#axes[1,0].set_xlabel('client ids')
#axes[1,1].set_xlabel('client ids')
#axes[2,2].set_xlabel('client ids')
attack_percent = 20
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    i += 1
for i in range(4):
    for j in range(4):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
    attack_percent += 10
#        a += 1
colors = ['black','red','magenta','indigo','orange','green','cyan','sienna','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline','acc-attack','asr-attack','mcr-attack','t_mcr-attack','acc-defense',
          'asr-defense','mcr-defense','t_mcr-defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_all_20_50')

# %% [markdown]
# # rounds 60-90 without marker

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 11))


axes[0,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[0,0].plot(rounds[0][:50], acc_18[0][:50],'r',label='attack')
axes[0,0].plot(rounds[0][:50], acc_18[1][:50],'g',label='defense')
#axes[5,0].set_xlabel('communication rounds')
axes[0,0].set_ylabel('accuracy')


axes[0,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[0,1].plot(rounds[0][:50], asr_18[0][:50],'m',label='attack')
axes[0,1].plot(rounds[0][:50], asr_18[1][:50],'c',label='defense')
#axes[5,1].set_xlabel('communication rounds')
axes[0,1].set_ylabel('attack success rate')

axes[0,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[0,2].plot(rounds[0][:50], mcr_18[0][:50],color='indigo',label='attack')
axes[0,2].plot(rounds[0][:50], mcr_18[1][:50],color='sienna',label='defense')
#axes[5,2].set_xlabel('communication rounds')
axes[0,2].set_ylabel('misclassification rate')

axes[0,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[0,3].plot(rounds[0][:50], t_mcr_18[0][:50],color='orange',label='attack')
axes[0,3].plot(rounds[0][:50], t_mcr_18[1][:50],'b',label='defense')
#axes[5,3].set_xlabel('communication rounds')
axes[0,3].set_ylabel('targeted misclassification rate')

axes[1,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[1,0].plot(rounds[0][:50], acc_21[0][:50],'r',label='attack')
axes[1,0].plot(rounds[0][:50], acc_21[1][:50],'g',label='defense')
#axes[6,0].set_xlabel('communication rounds')
axes[1,0].set_ylabel('accuracy')

axes[1,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[1,1].plot(rounds[0][:50], asr_21[0][:50],'m',label='attack')
axes[1,1].plot(rounds[0][:50], asr_21[1][:50],'c',label='defense')
#axes[6,1].set_xlabel('communication rounds')
axes[1,1].set_ylabel('attack success rate')

axes[1,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[1,2].plot(rounds[0][:50], mcr_21[0][:50],color='indigo',label='attack')
axes[1,2].plot(rounds[0][:50], mcr_21[1][:50],color='sienna',label='defense')
#axes[6,2].set_xlabel('communication rounds')
axes[1,2].set_ylabel('misclassification rate')

axes[1,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[1,3].plot(rounds[0][:50], t_mcr_21[0][:50],color='orange',label='attack')
axes[1,3].plot(rounds[0][:50], t_mcr_21[1][:50],'b',label='defense')
#axes[6,3].set_xlabel('communication rounds')
axes[1,3].set_ylabel('targeted misclassification rate')

axes[2,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[2,0].plot(rounds[0][:50], acc_24[0][:50],'r',label='attack')
axes[2,0].plot(rounds[0][:50], acc_24[1][:50],'g',label='defense')
#axes[7,0].set_xlabel('communication rounds')
axes[2,0].set_ylabel('accuracy')

axes[2,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[2,1].plot(rounds[0][:50], asr_24[0][:50],'m',label='attack')
axes[2,1].plot(rounds[0][:50], asr_24[1][:50],'c',label='defense')
#axes[7,1].set_xlabel('communication rounds')
axes[2,1].set_ylabel('attack success rate')

axes[2,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[2,2].plot(rounds[0][:50], mcr_24[0][:50],color='indigo',label='attack')
axes[2,2].plot(rounds[0][:50], mcr_24[1][:50],color='sienna',label='defense')
#axes[7,2].set_xlabel('communication rounds')
axes[2,2].set_ylabel('misclassification rate')

axes[2,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[2,3].plot(rounds[0][:50], t_mcr_24[0][:50],color='orange',label='attack')
axes[2,3].plot(rounds[0][:50], t_mcr_24[1][:50],'b',label='defense')
#axes[7,3].set_xlabel('communication rounds')
axes[2,3].set_ylabel('targeted misclassification rate')

axes[3,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[3,0].plot(rounds[0][:50], acc_27[0][:50],'r',label='attack')
axes[3,0].plot(rounds[0][:50], acc_27[1][:50],'g',label='defense')
#axes[8,0].set_xlabel('communication rounds')
axes[3,0].set_ylabel('accuracy')

axes[3,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[3,1].plot(rounds[0][:50], asr_27[0][:50],'m',label='attack')
axes[3,1].plot(rounds[0][:50], asr_27[1][:50],'c',label='defense')
#axes[8,1].set_xlabel('communication rounds')
axes[3,1].set_ylabel('attack success rate')

axes[3,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[3,2].plot(rounds[0][:50], mcr_27[0][:50],color='indigo',label='attack')
axes[3,2].plot(rounds[0][:50], mcr_27[1][:50],color='sienna',label='defense')
#axes[8,2].set_xlabel('communication rounds')
axes[3,2].set_ylabel('misclassification rate')

axes[3,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[3,3].plot(rounds[0][:50], t_mcr_27[0][:50],color='orange',label='attack')
axes[3,3].plot(rounds[0][:50], t_mcr_27[1][:50],'b',label='defense')
#axes[8,3].set_xlabel('communication rounds')
axes[3,3].set_ylabel('targeted misclassification rate')

#axes[0,0].set_ylabel('reconstruction loss')
#axes[1,0].set_ylabel('reconstruction loss')
#axes[2,0].set_ylabel('reconstruction loss')
#axes[1,0].set_xlabel('client ids')
#axes[1,1].set_xlabel('client ids')
#axes[2,2].set_xlabel('client ids')
attack_percent = 60
a = 97
i = 17
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    i += 1
for i in range(4):
    for j in range(4):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
    attack_percent += 10
#        a += 1
colors = ['black','red','magenta','indigo','orange','green','cyan','sienna','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline','acc-attack','asr-attack','mcr-attack','t_mcr-attack','acc-defense',
          'asr-defense','mcr-defense','t_mcr-defense']
#plt.legend(lines, labels)
plt.legend(lines, labels,bbox_to_anchor=(1.05,1.1))
#fig.subplots_adjust()
#axes.legend(bbox_to_anchor=(-1.05, 1.0), loc='upper left')
plt.tight_layout()
#plt.savefig('fashion_mnist_lfa_all_60_90')

# %% [markdown]
# # Subplot rounds 20-50 with marker

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(17, 11))

axes[0,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[0,0].plot(rounds[0][:50], acc_6[0][:50],'r',marker='>',label='attack')
axes[0,0].plot(rounds[0][:50], acc_6[1][:50],'g',marker='<',label='defense')
#axes[1,0].set_xlabel('communication rounds')
axes[0,0].set_ylabel('accuracy')

axes[0,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[0,1].plot(rounds[0][:50], asr_6[0][:50],'m',marker='>',label='attack')
axes[0,1].plot(rounds[0][:50], asr_6[1][:50],'c',marker='<',label='defense')
#axes[1,1].set_xlabel('communication rounds')
axes[0,1].set_ylabel('attack success rate')

axes[0,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[0,2].plot(rounds[0][:50], mcr_6[0][:50],color='indigo',marker='>',label='attack')
axes[0,2].plot(rounds[0][:50], mcr_6[1][:50],color='sienna',marker='<',label='defense')
#axes[1,2].set_xlabel('communication rounds')
axes[0,2].set_ylabel('misclassification rate')

axes[0,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[0,3].plot(rounds[0][:50], t_mcr_6[0][:50],color='orange',marker='>',label='attack')
axes[0,3].plot(rounds[0][:50], t_mcr_6[1][:50],'b',marker='<',label='defense')
#axes[1,3].set_xlabel('communication rounds')
axes[0,3].set_ylabel('targeted misclassification rate')

axes[1,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[1,0].plot(rounds[0][:50], acc_9[0][:50],'r',marker='>',label='attack')
axes[1,0].plot(rounds[0][:50], acc_9[1][:50],'g',marker='<',label='defense')
#axes[2,0].set_xlabel('communication rounds')
axes[1,0].set_ylabel('accuracy')

axes[1,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[1,1].plot(rounds[0][:50], asr_9[0][:50],'m',marker='>',label='attack')
axes[1,1].plot(rounds[0][:50], asr_9[1][:50],'c',marker='<',label='defense')
#axes[2,1].set_xlabel('communication rounds')
axes[1,1].set_ylabel('attack success rate')

axes[1,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[1,2].plot(rounds[0][:50], mcr_9[0][:50],color='indigo',marker='>',label='attack')
axes[1,2].plot(rounds[0][:50], mcr_9[1][:50],color='sienna',marker='<',label='defense')
#axes[2,2].set_xlabel('communication rounds')
axes[1,2].set_ylabel('misclassification rate')

axes[1,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[1,3].plot(rounds[0][:50], t_mcr_9[0][:50],color='orange',marker='>',label='attack')
axes[1,3].plot(rounds[0][:50], t_mcr_9[1][:50],'b',marker='<',label='defense')
#axes[2,3].set_xlabel('communication rounds')
axes[1,3].set_ylabel('targeted misclassification rate')

axes[2,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[2,0].plot(rounds[0][:50], acc_12[0][:50],'r',marker='>',label='attack')
axes[2,0].plot(rounds[0][:50], acc_12[1][:50],'g',marker='<',label='defense')
#axes[3,0].set_xlabel('communication rounds')
axes[2,0].set_ylabel('accuracy')

axes[2,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[2,1].plot(rounds[0][:50], asr_12[0][:50],'m',marker='>',label='attack')
axes[2,1].plot(rounds[0][:50], asr_12[1][:50],'c',marker='<',label='defense')
#axes23,1].set_xlabel('communication rounds')
axes[2,1].set_ylabel('attack success rate')

axes[2,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[2,2].plot(rounds[0][:50], mcr_12[0][:50],color='indigo',marker='>',label='attack')
axes[2,2].plot(rounds[0][:50], mcr_12[1][:50],color='sienna',marker='<',label='defense')
#axes[3,2].set_xlabel('communication rounds')
axes[2,2].set_ylabel('misclassification rate')

axes[2,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[2,3].plot(rounds[0][:50], t_mcr_12[0][:50],color='orange',marker='>',label='attack')
axes[2,3].plot(rounds[0][:50], t_mcr_12[1][:50],'b',marker='<',label='defense')
#axes[3,3].set_xlabel('communication rounds')
axes[2,3].set_ylabel('targeted misclassification rate')

axes[3,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[3,0].plot(rounds[0][:50], acc_15[0][:50],'r',marker='>',label='attack')
axes[3,0].plot(rounds[0][:50], acc_15[1][:50],'g',marker='<',label='defense')
#axes[4,0].set_xlabel('communication rounds')
axes[3,0].set_ylabel('accuracy')

axes[3,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[3,1].plot(rounds[0][:50], asr_15[0][:50],'m',marker='>',label='attack')
axes[3,1].plot(rounds[0][:50], asr_15[1][:50],'c',marker='<',label='defense')
#axes[4,1].set_xlabel('communication rounds')
axes[3,1].set_ylabel('attack success rate')

axes[3,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[3,2].plot(rounds[0][:50], mcr_15[0][:50],color='indigo',marker='>',label='attack')
axes[3,2].plot(rounds[0][:50], mcr_15[1][:50],color='sienna',marker='<',label='defense')
#axes[4,2].set_xlabel('communication rounds')
axes[3,2].set_ylabel('misclassification rate')

axes[3,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[3,3].plot(rounds[0][:50], t_mcr_15[0][:50],color='orange',marker='>',label='attack')
axes[3,3].plot(rounds[0][:50], t_mcr_15[1][:50],'b',marker='<',label='defense')
#axes[4,3].set_xlabel('communication rounds')
axes[3,3].set_ylabel('targeted misclassification rate')


#axes[0,0].set_ylabel('reconstruction loss')
#axes[1,0].set_ylabel('reconstruction loss')
#axes[2,0].set_ylabel('reconstruction loss')
#axes[1,0].set_xlabel('client ids')
#axes[1,1].set_xlabel('client ids')
#axes[2,2].set_xlabel('client ids')
attack_percent = 20
a = 97
i = 1
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    i += 1
for i in range(4):
    for j in range(4):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
    attack_percent += 10
#        a += 1
colors = ['black','red','magenta','indigo','orange','green','cyan','sienna','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline','acc-attack','asr-attack','mcr-attack','t_mcr-attack','acc-defense',
          'asr-defense','mcr-defense','t_mcr-defense']
#plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.legend(lines, labels,bbox_to_anchor=(1.05, 1.0), loc='upper left')
#axes.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_all_20_50_marker')

# %% [markdown]
# # Round 60-90 with marker

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(17, 11))


axes[0,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[0,0].plot(rounds[0][:50], acc_18[0][:50],'r',marker='>',label='attack')
axes[0,0].plot(rounds[0][:50], acc_18[1][:50],'g',marker='<',label='defense')
#axes[5,0].set_xlabel('communication rounds')
axes[0,0].set_ylabel('accuracy')


axes[0,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[0,1].plot(rounds[0][:50], asr_18[0][:50],'m',marker='>',label='attack')
axes[0,1].plot(rounds[0][:50], asr_18[1][:50],'c',marker='<',label='defense')
#axes[5,1].set_xlabel('communication rounds')
axes[0,1].set_ylabel('attack success rate')

axes[0,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[0,2].plot(rounds[0][:50], mcr_18[0][:50],color='indigo',marker='>',label='attack')
axes[0,2].plot(rounds[0][:50], mcr_18[1][:50],color='sienna',marker='<',label='defense')
#axes[5,2].set_xlabel('communication rounds')
axes[0,2].set_ylabel('misclassification rate')

axes[0,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[0,3].plot(rounds[0][:50], t_mcr_18[0][:50],color='orange',marker='>',label='attack')
axes[0,3].plot(rounds[0][:50], t_mcr_18[1][:50],'b',marker='<',label='defense')
#axes[5,3].set_xlabel('communication rounds')
axes[0,3].set_ylabel('targeted misclassification rate')

axes[1,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[1,0].plot(rounds[0][:50], acc_21[0][:50],'r',marker='>',label='attack')
axes[1,0].plot(rounds[0][:50], acc_21[1][:50],'g',marker='<',label='defense')
#axes[6,0].set_xlabel('communication rounds')
axes[1,0].set_ylabel('accuracy')

axes[1,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[1,1].plot(rounds[0][:50], asr_21[0][:50],'m',marker='>',label='attack')
axes[1,1].plot(rounds[0][:50], asr_21[1][:50],'c',marker='<',label='defense')
#axes[6,1].set_xlabel('communication rounds')
axes[1,1].set_ylabel('attack success rate')

axes[1,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[1,2].plot(rounds[0][:50], mcr_21[0][:50],color='indigo',marker='>',label='attack')
axes[1,2].plot(rounds[0][:50], mcr_21[1][:50],color='sienna',marker='<',label='defense')
#axes[6,2].set_xlabel('communication rounds')
axes[1,2].set_ylabel('misclassification rate')

axes[1,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[1,3].plot(rounds[0][:50], t_mcr_21[0][:50],color='orange',marker='>',label='attack')
axes[1,3].plot(rounds[0][:50], t_mcr_21[1][:50],'b',marker='<',label='defense')
#axes[6,3].set_xlabel('communication rounds')
axes[1,3].set_ylabel('targeted misclassification rate')

axes[2,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[2,0].plot(rounds[0][:50], acc_24[0][:50],'r',marker='>',label='attack')
axes[2,0].plot(rounds[0][:50], acc_24[1][:50],'g',marker='<',label='defense')
#axes[7,0].set_xlabel('communication rounds')
axes[2,0].set_ylabel('accuracy')

axes[2,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[2,1].plot(rounds[0][:50], asr_24[0][:50],'m',marker='>',label='attack')
axes[2,1].plot(rounds[0][:50], asr_24[1][:50],'c',marker='<',label='defense')
#axes[7,1].set_xlabel('communication rounds')
axes[2,1].set_ylabel('attack success rate')

axes[2,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[2,2].plot(rounds[0][:50], mcr_24[0][:50],color='indigo',marker='>',label='attack')
axes[2,2].plot(rounds[0][:50], mcr_24[1][:50],color='sienna',marker='<',label='defense')
#axes[7,2].set_xlabel('communication rounds')
axes[2,2].set_ylabel('misclassification rate')

axes[2,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[2,3].plot(rounds[0][:50], t_mcr_24[0][:50],color='orange',marker='>',label='attack')
axes[2,3].plot(rounds[0][:50], t_mcr_24[1][:50],'b',marker='<',label='defense')
#axes[7,3].set_xlabel('communication rounds')
axes[2,3].set_ylabel('targeted misclassification rate')

axes[3,0].plot(rounds[0][:50], acc_0[0][:50],'k',label='no attack')
axes[3,0].plot(rounds[0][:50], acc_27[0][:50],'r',marker='>',label='attack')
axes[3,0].plot(rounds[0][:50], acc_27[1][:50],'g',marker='<',label='defense')
#axes[8,0].set_xlabel('communication rounds')
axes[3,0].set_ylabel('accuracy')

axes[3,1].plot(rounds[0][:50], asr_0[0][:50],'k',label='no attack')
axes[3,1].plot(rounds[0][:50], asr_27[0][:50],'m',marker='>',label='attack')
axes[3,1].plot(rounds[0][:50], asr_27[1][:50],'c',marker='<',label='defense')
#axes[8,1].set_xlabel('communication rounds')
axes[3,1].set_ylabel('attack success rate')

axes[3,2].plot(rounds[0][:50], mcr_0[0][:50],'k',label='no attack')
axes[3,2].plot(rounds[0][:50], mcr_27[0][:50],color='indigo',marker='>',label='attack')
axes[3,2].plot(rounds[0][:50], mcr_27[1][:50],color='sienna',marker='<',label='defense')
#axes[8,2].set_xlabel('communication rounds')
axes[3,2].set_ylabel('misclassification rate')

axes[3,3].plot(rounds[0][:50], t_mcr_0[0][:50],'k',label='no attack')
axes[3,3].plot(rounds[0][:50], t_mcr_27[0][:50],color='orange',marker='>',label='attack')
axes[3,3].plot(rounds[0][:50], t_mcr_27[1][:50],'b',marker='<',label='defense')
#axes[8,3].set_xlabel('communication rounds')
axes[3,3].set_ylabel('targeted misclassification rate')

#axes[0,0].set_ylabel('reconstruction loss')
#axes[1,0].set_ylabel('reconstruction loss')
#axes[2,0].set_ylabel('reconstruction loss')
#axes[1,0].set_xlabel('client ids')
#axes[1,1].set_xlabel('client ids')
#axes[2,2].set_xlabel('client ids')
attack_percent = 60
a = 97
i = 17
for ax in axes.flat:
    ax.set(xlabel='communication rounds\n\n ({})'.format(intToRoman(i)))
    i += 1
for i in range(4):
    for j in range(4):
        axes[i,j].set_title('{}% attacker'.format(attack_percent))
#        axes[i,j].set_title('% of attacker = {}%'.format(attack_percent))
#        #axes[i,j].set_xlabel('communication rounds')
#        #axes[i,j].set_ylabel('attack success rate / accuracy')
#        #axes[i,j].legend()
    attack_percent += 10
#        a += 1
colors = ['black','red','magenta','indigo','orange','green','cyan','sienna','blue']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels = ['baseline','acc-attack','asr-attack','mcr-attack','t_mcr-attack','acc-defense',
          'asr-defense','mcr-defense','t_mcr-defense']
#plt.legend(lines, labels)
plt.legend(lines, labels,bbox_to_anchor=(1.05,1.1))
#fig.subplots_adjust()
#axes.legend(bbox_to_anchor=(-1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.savefig('fashion_mnist_lfa_all_60_90_marker')
